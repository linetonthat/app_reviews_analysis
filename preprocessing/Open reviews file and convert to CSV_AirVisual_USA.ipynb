# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Preprocessing,-exploration-and-export-of-app-reviews-[USA-appstore]" data-toc-modified-id="Preprocessing,-exploration-and-export-of-app-reviews-[USA-appstore]-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Preprocessing, exploration and export of app reviews [USA appstore]</a></span><ul class="toc-item"><li><span><a href="#Load-data" data-toc-modified-id="Load-data-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Load data</a></span></li><li><span><a href="#Ratings" data-toc-modified-id="Ratings-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Ratings</a></span></li><li><span><a href="#Detect-language" data-toc-modified-id="Detect-language-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Detect language</a></span></li><li><span><a href="#Sort-data" data-toc-modified-id="Sort-data-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Sort data</a></span></li><li><span><a href="#Export-data" data-toc-modified-id="Export-data-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Export data</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Preprocessing, exploration and export of app reviews [USA appstore]

# %% [markdown]
# We have scraped reviews on a [specific app](https://apps.apple.com/fr/app/airvisual-qualit%C3%A9-de-lair/id1048912974#see-all/reviews) in the French appstore. This app is related to air quality. Our goal is to analyse these reviews to try to find out about :
# * usages
# * most relevant app features
# * "missing" app features, or features that users would like the app to have
# * technical issues.
#
# Data preparation will be key to help analyse the reviews, such as sorting reviews according to selected criteria.  This will also give us the opportunity to test some NLP tools as needed (language detection, sentiment analysis...).

# %%
import pandas as pd
from langdetect import detect
import warnings
warnings.filterwarnings('ignore')
import os

# %% [markdown]
# ## Load data

# %%
path = os.getcwd()
filename ='app_reviews_us.json'

# %%
df = pd.read_json(path+"/../data/0_scraped_data/"+filename)

# %%
df.head()
# Out:
#     review_id  rating                                   title  \
# 0  1444976984       5                 Did my research, get it
# 1  5106173514       5                      Your AQI in an app
# 2  4525953569       5                     Potential Lifesaver
# 3  3058376013       1  Forecast data is completely unreliable
# 4  5333716395       5                           Peace of Mind
#
#             review_date  user_name  \
# 0  2016-09-05T14:22:49Z  Grindelli
# 1  2019-11-08T19:14:02Z   Kido@PDX
# 2  2019-07-27T13:37:32Z     ttu101
# 3  2018-08-13T11:40:29Z   c0rlette
# 4  2019-12-29T08:29:19Z  TangoXray
#
#                                               review  response_id  \
# 0  I have lived in China for 3 years and have a t...          NaN
# 1  This free app can help you with information an...          NaN
# 2  It is only just beginning to seep into the pub...          NaN
# 3  While current local condition air quality seem...          NaN
# 4  The app is so helpful as a quick reference to ...          NaN
#
#   dev_response response_date
# 0          NaN           NaN
# 1          NaN           NaN
# 2          NaN           NaN
# 3          NaN           NaN
# 4          NaN           NaN

# %%
df.columns
# Out:
# Index(['review_id', 'rating', 'title', 'review_date', 'user_name', 'review',
#        'response_id', 'dev_response', 'response_date'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3097 entries, 0 to 3096
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   review_id      3097 non-null   int64
#  1   rating         3097 non-null   int64
#  2   title          3097 non-null   object
#  3   review_date    3097 non-null   object
#  4   user_name      3097 non-null   object
#  5   review         3097 non-null   object
#  6   response_id    7 non-null      float64
#  7   dev_response   7 non-null      object
#  8   response_date  7 non-null      object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 217.9+ KB

# %%
df['review']
# Out:
# 0       I have lived in China for 3 years and have a t...
# 1       This free app can help you with information an...
# 2       It is only just beginning to seep into the pub...
# 3       While current local condition air quality seem...
# 4       The app is so helpful as a quick reference to ...
#                               ...
# 3092    Easy to read and understand. Visually pleasing...
# 3093           Très bonne application, fiable et précise.
# 3094                                        best app ever
# 3095    Having allergies is annoying but I’m glad to s...
# 3096    I got this app a few weeks ago because it seem...
# Name: review, Length: 3097, dtype: object

# %% [markdown]
# ## Ratings

# %%
# assess the distribution of ratings
df['rating'].value_counts()
# Out:
# 5    2518
# 4     383
# 1      89
# 3      71
# 2      36
# Name: rating, dtype: int64

# %%
# assess mean rating
df['rating'].mean()
# Out:
# 4.680658701969648

# %% [markdown]
# ## Detect language

# %%
# Define a function to identify language and catch exceptions
def lang_detect(text):
    # use deterministic approach for language detection
    from langdetect import DetectorFactory
    DetectorFactory.seed = 0
    try:
        return detect(text)
    except:
        return "language not detected"

# %%
# Detect the language used in the reviews
df['lang-r'] = df['review'].apply(lang_detect)

# %%
# What are the detected languages?
df['lang-r'].unique()
# Out:
# array(['en', 'it', 'ro', 'no', 'ca', 'et', 'af', 'da', 'tr', 'sv', 'pt',
#        'sq', 'sl', 'tl', 'de', 'nl', 'so', 'es', 'cs', 'fr',
#        'language not detected', 'sw', 'fi', 'id', 'cy', 'vi', 'sk', 'hr',
#        'pl', 'ko', 'ja', 'zh-cn', 'uk', 'th', 'ru', 'hu'], dtype=object)

# %%
# What is the distribution of the detected languages?
df['lang-r'].value_counts()
# Out:
# en                       2641
# so                         69
# vi                         67
# af                         42
# ko                         42
# language not detected      28
# ro                         25
# zh-cn                      23
# it                         19
# ca                         15
# es                         14
# fr                         13
# th                         10
# nl                          8
# da                          7
# cy                          7
# no                          6
# sw                          6
# sl                          6
# de                          6
# id                          6
# tl                          5
# sq                          4
# et                          4
# sv                          4
# tr                          4
# cs                          3
# ja                          2
# fi                          2
# sk                          2
# pt                          2
# ru                          1
# uk                          1
# hu                          1
# hr                          1
# pl                          1
# Name: lang-r, dtype: int64

# %% [markdown]
# As expected, most reviews are detected as being in English, since reviews were collected from the US appstore.

# %%
# Look at reviews where the language could not be detected
df.loc[df['lang-r']=='language not detected']
# Out:
#        review_id  rating                                  title  \
# 2240  4620151372       5                          Breath better
# 2271  5697230971       5  Great App for Determining Air Quality
# 2284  3060787039       5                             Works well
# 2331  5410556931       5                    Great and reliable!
# 2394  5418929112       5                            Very useful
# 2511  3649027847       5                           So helpful !
# 2534  3437121196       5      Best pollution detection app ever
# 2567  4925884828       5                               Phongtag
# 2618  3997524762       5                           👍 Good stuff
# 2629  5308269360       5                                Great!!
# 2665  5315922283       5                                Perfect
# 2736  5718439110       5                                 Thanks
# 2743  5356826862       5                               the best
# 2759  2319335238       5                                   good
# 2762  5140034826       5                              v helpful
# 2765  3880732602       5                                   good
# 2772  5188386842       5                                   Good
# 2776  5272025276       5                                 TEC-11
# 2778  3786735977       5                                   Good
# 2786  5280972317       5                                     👍👍
# 2805  3914234091       4                                    ມັກ
# 2806  5347473828       3                                      👍
# 2879  5341679093       5                               No.1 app
# 2883  5318180926       5                               Mr.Nazem
# 3037  5553769683       5                          Excelente app
# 3038  1477453009       1               الدول العربية غير متوفرة
# 3039  4773558618       5                         Help Pekanbaru
# 3053  5220879442       5                             ❤️❤️❤️❤️❤️
#
#                review_date             user_name      review  response_id  \
# 2240  2019-08-15T14:02:32Z  PERRYPOST RESTERAUNT           ?          NaN
# 2271  2020-03-22T16:07:07Z                Teysha        ....          NaN
# 2284  2018-08-14T01:13:17Z         EvolutionXIII          👍🏼          NaN
# 2331  2020-01-16T12:26:19Z               star.p_          👍🏽          NaN
# 2394  2020-01-18T13:21:55Z            Jack111188          ..          NaN
# 2511  2019-01-14T12:23:36Z        bammmmmmmm1551        ❤️❤️          NaN
# 2534  2018-11-19T20:53:35Z       samuel_banapour        !!!😜          NaN
# 2567  2019-10-12T00:17:38Z              phongtag           6          NaN
# 2618  2019-04-11T07:02:44Z             Intermiss          👍👍          NaN
# 2629  2019-12-23T11:18:18Z               Pixon99          5*          NaN
# 2665  2019-12-25T04:32:31Z           danialaryan          👌😀          NaN
# 2736  2020-03-27T00:10:19Z             seoul mom  👍🏻👍🏻👍🏻👍🏻👍🏻          NaN
# 2743  2020-01-03T20:29:40Z         Master Kasraa          👌🏻          NaN
# 2759  2018-03-18T12:07:50Z              Aglimmer           🤗          NaN
# 2762  2019-11-15T05:25:16Z        bebopneverdied        🧙‍♀️          NaN
# 2765  2019-03-14T15:24:01Z           muay opa ty          👍👍          NaN
# 2772  2019-11-23T21:17:05Z         Ho Thanh Thao         👍👍👍          NaN
# 2776  2019-12-14T14:56:43Z                TEC-11           👍          NaN
# 2778  2019-02-19T00:08:17Z                Iaicem    👍🏻👍🏻👍🏻👍🏻          NaN
# 2786  2019-12-16T21:47:38Z              darijajm          👍👍          NaN
# 2805  2019-03-23T01:09:14Z              Kikosalu  ເປັນປະໂຫຍດ          NaN
# 2806  2020-01-01T16:37:56Z          john Ibex 83           👍          NaN
# 2879  2019-12-31T07:28:26Z             Tarpanjeh           👍          NaN
# 2883  2019-12-25T15:54:30Z              Mr.Nazem           👍          NaN
# 3037  2020-02-19T21:55:51Z          Narvaezjuanl          :)          NaN
# 3038  2016-11-02T19:18:36Z              لولي1988        👎🏻👎🏻          NaN
# 3039  2019-09-14T05:12:10Z         FALLO UT RBOI          :(          NaN
# 3053  2019-12-01T13:07:28Z                 Aaa^+  ❤️❤️❤️❤️❤️          NaN
#
#      dev_response response_date                 lang-r
# 2240          NaN           NaN  language not detected
# 2271          NaN           NaN  language not detected
# 2284          NaN           NaN  language not detected
# 2331          NaN           NaN  language not detected
# 2394          NaN           NaN  language not detected
# 2511          NaN           NaN  language not detected
# 2534          NaN           NaN  language not detected
# 2567          NaN           NaN  language not detected
# 2618          NaN           NaN  language not detected
# 2629          NaN           NaN  language not detected
# 2665          NaN           NaN  language not detected
# 2736          NaN           NaN  language not detected
# 2743          NaN           NaN  language not detected
# 2759          NaN           NaN  language not detected
# 2762          NaN           NaN  language not detected
# 2765          NaN           NaN  language not detected
# 2772          NaN           NaN  language not detected
# 2776          NaN           NaN  language not detected
# 2778          NaN           NaN  language not detected
# 2786          NaN           NaN  language not detected
# 2805          NaN           NaN  language not detected
# 2806          NaN           NaN  language not detected
# 2879          NaN           NaN  language not detected
# 2883          NaN           NaN  language not detected
# 3037          NaN           NaN  language not detected
# 3038          NaN           NaN  language not detected
# 3039          NaN           NaN  language not detected
# 3053          NaN           NaN  language not detected

# %% [markdown]
# Most reviews where the language could not be detected are made of emoticones. Some of mathematical symbols.

# %% [markdown]
# Given the number of reviews, we'll export only those where review language was detected as being English.

# %%
# check cases where language review is not French or English
dfout = df.loc[df['lang-r']=='en']

# %%
dfout['lang'] = 'en'

# %%
del dfout['lang-r']

# %%
dfout.head()
# Out:
#        review_id  rating                                              title  \
# 3095  6121840341       5  Happy to finally see when and why I can’t brea...
# 982   6114444527       5                                              Super
# 1965  6114325210       5                                          Great App
# 797   6111838742       5                    Great app for filtering the air
# 962   6104666348       5                                    I look everyday
#
#                review_date       user_name  \
# 3095  2020-06-25T23:18:57Z      Abbsteroni
# 982   2020-06-24T02:12:59Z       WillJosue
# 1965  2020-06-24T01:31:38Z       Nejinater
# 797   2020-06-23T11:01:04Z      Jamieissad
# 962   2020-06-21T14:29:25Z  TorchPitchfork
#
#                                                  review  response_id  \
# 3095  Having allergies is annoying but I’m glad to s...          NaN
# 982          Easy to keep track on specific Local areas          NaN
# 1965                          Full of good information!          NaN
# 797   Tells you everything you need to know about th...          NaN
# 962   This is part of my daily planning. I love the ...          NaN
#
#      dev_response response_date lang
# 3095          NaN           NaN   en
# 982           NaN           NaN   en
# 1965          NaN           NaN   en
# 797           NaN           NaN   en
# 962           NaN           NaN   en

# %%
len(dfout)
# Out:
# 2641

# %% [markdown]
# ## Sort data

# %%
dfout.sort_values(by=['lang','rating','review_date'], inplace = True, ascending = False)

# %%
dfout
# Out:
#        review_id  rating                                              title  \
# 3095  6121840341       5  Happy to finally see when and why I can’t brea...
# 982   6114444527       5                                              Super
# 1965  6114325210       5                                          Great App
# 797   6111838742       5                    Great app for filtering the air
# 962   6104666348       5                                    I look everyday
# ...          ...     ...                                                ...
# 664   1606714251       1             App Didn't Recognize Air Quality Alert
# 7     1601019558       1                               Horribly inaccurate.
# 2828  1404336381       1                                            Bad App
# 2835  1396610393       1                                 Research Scientist
# 3096  1343052514       1                                      Has Potential
#
#                review_date               user_name  \
# 3095  2020-06-25T23:18:57Z              Abbsteroni
# 982   2020-06-24T02:12:59Z               WillJosue
# 1965  2020-06-24T01:31:38Z               Nejinater
# 797   2020-06-23T11:01:04Z              Jamieissad
# 962   2020-06-21T14:29:25Z          TorchPitchfork
# ...                    ...                     ...
# 664   2017-05-06T13:07:12Z  Tired of Being Hounded
# 7     2017-04-30T01:43:28Z          Galia Stauffer
# 2828  2016-07-02T22:34:12Z                  1nEden
# 2835  2016-06-18T18:57:39Z                Elicia P
# 3096  2016-03-05T10:34:28Z            Snwbrdrgrl79
#
#                                                  review  response_id  \
# 3095  Having allergies is annoying but I’m glad to s...          NaN
# 982          Easy to keep track on specific Local areas          NaN
# 1965                          Full of good information!          NaN
# 797   Tells you everything you need to know about th...          NaN
# 962   This is part of my daily planning. I love the ...          NaN
# ...                                                 ...          ...
# 664   National Weather Service had issued an Ozone A...          NaN
# 7     I live in South Korea and have for a total of ...          NaN
# 2828  The info is inaccurate. My location had a gree...          NaN
# 2835  This app is completely inaccurate for Philadel...          NaN
# 3096  I got this app a few weeks ago because it seem...          NaN
#
#      dev_response response_date lang
# 3095          NaN           NaN   en
# 982           NaN           NaN   en
# 1965          NaN           NaN   en
# 797           NaN           NaN   en
# 962           NaN           NaN   en
# ...           ...           ...  ...
# 664           NaN           NaN   en
# 7             NaN           NaN   en
# 2828          NaN           NaN   en
# 2835          NaN           NaN   en
# 3096          NaN           NaN   en
#
# [2641 rows x 10 columns]

# %% [markdown]
# ## Export data

# %%
# export to csv
dfout.to_csv('app_reviews_airvisual-air-quality-forecast_1048912974_by_lang_us.csv', encoding='utf-8-sig', sep =';')

# %% [markdown]
# NB: To detect language, other tools are available and might yield better results.
