# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Extract-opinion-units-and-save-as-CSV" data-toc-modified-id="Extract-opinion-units-and-save-as-CSV-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Extract opinion units and save as CSV</a></span></li></ul></div>

# %% [markdown]
# # Extract opinion units and save as CSV

# %%
import os
import pandas as pd

# %%
path = os.getcwd()

# %%
subfolder = "/../data/2_opinion_units/"

# %%
filename = "app_reviews_airvisual-air-quality-forecast_1048912974_by_lang_us_exp_abb_ou_v3.csv"

# %%
df = pd.read_csv(path+subfolder+filename)

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1   review_id  rating  \
# 0           0             0            3095  6121840341       5
# 1           1             0            3095  6121840341       5
# 2           2             0            3095  6121840341       5
# 3           3             1             982  6114444527       5
# 4           4             1             982  6114444527       5
#
#                                                title           review_date  \
# 0  Happy to finally see when and why I can’t brea...  2020-06-25T23:18:57Z
# 1  Happy to finally see when and why I can’t brea...  2020-06-25T23:18:57Z
# 2  Happy to finally see when and why I can’t brea...  2020-06-25T23:18:57Z
# 3                                              Super  2020-06-24T02:12:59Z
# 4                                              Super  2020-06-24T02:12:59Z
#
#     user_name                                             review  response_id  \
# ...

# %%
del df['Unnamed: 0']

# %%
del df['Unnamed: 0.1']

# %%
del df['Unnamed: 0.1.1']

# %%
df.head()
# Out:
#     review_id  rating                                              title  \
# 0  6121840341       5  Happy to finally see when and why I can’t brea...
# 1  6121840341       5  Happy to finally see when and why I can’t brea...
# 2  6121840341       5  Happy to finally see when and why I can’t brea...
# 3  6114444527       5                                              Super
# 4  6114444527       5                                              Super
#
#             review_date   user_name  \
# 0  2020-06-25T23:18:57Z  Abbsteroni
# 1  2020-06-25T23:18:57Z  Abbsteroni
# 2  2020-06-25T23:18:57Z  Abbsteroni
# 3  2020-06-24T02:12:59Z   WillJosue
# 4  2020-06-24T02:12:59Z   WillJosue
#
#                                               review  response_id  \
# 0  Having allergies is annoying but I’m glad to s...          NaN
# 1  Having allergies is annoying but I’m glad to s...          NaN
# 2  Having allergies is annoying but I’m glad to s...          NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8275 entries, 0 to 8274
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   review_id        8275 non-null   int64
#  1   rating           8275 non-null   int64
#  2   title            8275 non-null   object
#  3   review_date      8275 non-null   object
#  4   user_name        8275 non-null   object
#  5   review           8275 non-null   object
#  6   response_id      41 non-null     float64
#  7   dev_response     41 non-null     object
#  8   response_date    41 non-null     object
#  9   lang             8275 non-null   object
#  10  title_expanded   8275 non-null   object
#  11  review_expanded  8275 non-null   object
#  12  opinion_unit     8275 non-null   object
#  13  opi_id           8275 non-null   int64
# dtypes: float64(1), int64(3), object(10)
# memory usage: 905.2+ KB

# %%
df.tail()
# Out:
#        review_id  rating          title           review_date     user_name  \
# 8270  1343052514       1  Has Potential  2016-03-05T10:34:28Z  Snwbrdrgrl79
# 8271  1343052514       1  Has Potential  2016-03-05T10:34:28Z  Snwbrdrgrl79
# 8272  1343052514       1  Has Potential  2016-03-05T10:34:28Z  Snwbrdrgrl79
# 8273  1343052514       1  Has Potential  2016-03-05T10:34:28Z  Snwbrdrgrl79
# 8274  1343052514       1  Has Potential  2016-03-05T10:34:28Z  Snwbrdrgrl79
#
#                                                  review  response_id  \
# 8270  I got this app a few weeks ago because it seem...          NaN
# 8271  I got this app a few weeks ago because it seem...          NaN
# 8272  I got this app a few weeks ago because it seem...          NaN
# 8273  I got this app a few weeks ago because it seem...          NaN
# 8274  I got this app a few weeks ago because it seem...          NaN
#
#      dev_response response_date lang title_expanded  \
# ...

# %%
df_out = df[['opi_id', 'opinion_unit', 'review_id', 'rating']]

# %%
df_out
# Out:
#       opi_id                                       opinion_unit   review_id  \
# 0          0  Happy to finally see when and why I ca n’t bre...  6121840341
# 1          1                       Having allergies is annoying  6121840341
# 2          2  but I ’m glad to see this and know when to tak...  6121840341
# 3          3                                              Super  6114444527
# 4          4         Easy to keep track on specific Local areas  6114444527
# ...      ...                                                ...         ...
# 8270    8270  I 'm currently residing in Sasebo Japan , wher...  1343052514
# 8271    8271              I have a 9 mos old son and a 5 yr old  1343052514
# 8272    8272  I 'm trying to keep from developing childhood ...  1343052514
# 8273    8273    That 's why air quality is so important to me .  1343052514
# 8274    8274                Hope they can work out the bugs ! !  1343052514
#
#       rating
# 0          5
# 1          5
# ...

# %%
export_filename = "opi_units_"+filename[:-29][12:]+".csv"
export_filename
# Out:
# 'opi_units_airvisual-air-quality-forecast_1048912974.csv'

# %%
df_out.to_csv(path+subfolder+export_filename, sep = ';')
