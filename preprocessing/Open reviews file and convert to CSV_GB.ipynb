# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Preprocessing,-exploration-and-export-of-app-reviews" data-toc-modified-id="Preprocessing,-exploration-and-export-of-app-reviews-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Preprocessing, exploration and export of app reviews</a></span><ul class="toc-item"><li><span><a href="#Load-data" data-toc-modified-id="Load-data-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Load data</a></span></li><li><span><a href="#Ratings" data-toc-modified-id="Ratings-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Ratings</a></span></li><li><span><a href="#Detect-language" data-toc-modified-id="Detect-language-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Detect language</a></span></li><li><span><a href="#Sort-data" data-toc-modified-id="Sort-data-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Sort data</a></span></li><li><span><a href="#Export-data" data-toc-modified-id="Export-data-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Export data</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Preprocessing, exploration and export of app reviews

# %% [markdown]
# We have scraped reviews on a [specific app](https://apps.apple.com/fr/app/airvisual-qualit%C3%A9-de-lair/id1048912974#see-all/reviews) in the French appstore. This app is related to air quality. Our goal is to analyse these reviews to try to find out about :
# * usages
# * most relevant app features
# * "missing" app features, or features that users would like the app to have
# * technical issues.
#
# Data preparation will be key to help analyse the reviews, such as sorting reviews according to selected criteria.  This will also give us the opportunity to test some NLP tools as needed (language detection, sentiment analysis...).

# %%
import pandas as pd
from langdetect import detect
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load data

# %%
#filename = 'app_reviews_airvisual-air-quality-forecast_1048912974.json'
filename ='app_reviews_en.json' # from Great Britain appstore

# %%
df = pd.read_json(filename)

# %%
df.head()
# Out:
#     review_id  rating                      title           review_date  \
# 0  4915894551       5           A tragic reality  2019-10-10T01:06:52Z
# 1  5387399470       5  Really useful information  2020-01-11T01:19:08Z
# 2  4057061182       5            Air quality app  2019-04-25T07:07:47Z
# 3  4858351034       5        Accurate & Reliable  2019-09-29T07:38:33Z
# 4  3883883779       5           Best aqi app yet  2019-03-15T12:07:55Z
#
#          user_name                                             review  \
# 0          Si & Ro  Amazingly helpful app, both for health and as ...
# 1           Suez62  We have an ‘eco’ woodburner and as an asthmati...
# 2  # alone at xmas  I was introduced to this app via a friend who ...
# 3       r2thebizel  Very clear, easy to use and engaging. Very rel...
# 4          jhugs43  I’ve tried several aqi apps over the years, mo...
#
#    response_id dev_response response_date
# 0          NaN          NaN           NaN
# 1          NaN          NaN           NaN
# 2          NaN          NaN           NaN
# 3          NaN          NaN           NaN
# 4          NaN          NaN           NaN

# %%
df.columns
# Out:
# Index(['review_id', 'rating', 'title', 'review_date', 'user_name', 'review',
#        'response_id', 'dev_response', 'response_date'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   review_id      243 non-null    int64
#  1   rating         243 non-null    int64
#  2   title          243 non-null    object
#  3   review_date    243 non-null    object
#  4   user_name      243 non-null    object
#  5   review         243 non-null    object
#  6   response_id    2 non-null      float64
#  7   dev_response   2 non-null      object
#  8   response_date  2 non-null      object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 17.2+ KB

# %%
df['review']
# Out:
# 0      Amazingly helpful app, both for health and as ...
# 1      We have an ‘eco’ woodburner and as an asthmati...
# 2      I was introduced to this app via a friend who ...
# 3      Very clear, easy to use and engaging. Very rel...
# 4      I’ve tried several aqi apps over the years, mo...
#                              ...
# 238                                       Thanks the app
# 239    Living in Baoding, China this app is essential...
# 240                Good app gives a realistic assessment
# 241             Pretty good. Will recommend to everyone.
# 242                      Great App! Needs more publicity
# Name: review, Length: 243, dtype: object

# %% [markdown]
# ## Ratings

# %%
# assess the distribution of ratings
df['rating'].value_counts()
# Out:
# 5    203
# 4     30
# 3      5
# 2      3
# 1      2
# Name: rating, dtype: int64

# %%
# assess mean rating
df['rating'].mean()
# Out:
# 4.765432098765432

# %% [markdown]
# ## Detect language

# %%
# Define a function to identify language and catch exceptions
def lang_detect(text):
    # use deterministic approach for language detection
    from langdetect import DetectorFactory
    DetectorFactory.seed = 0
    try:
        return detect(text)
    except:
        return "language not detected"

# %%
# Detect the language used in the reviews
df['lang-r'] = df['review'].apply(lang_detect)

# %%
# What are the detected languages?
df['lang-r'].unique()
# Out:
# array(['en', 'af', 'nl', 'et', 'de', 'it', 'language not detected', 'tr',
#        'so', 'fr', 'sk', 'ru', 'zh-cn', 'zh-tw', 'es', 'sv'], dtype=object)

# %%
# What is the distribution of the detected languages?
df['lang-r'].value_counts()
# Out:
# en                       218
# so                         4
# af                         3
# language not detected      2
# it                         2
# zh-cn                      2
# et                         2
# fr                         2
# sv                         1
# ru                         1
# sk                         1
# es                         1
# de                         1
# zh-tw                      1
# tr                         1
# nl                         1
# Name: lang-r, dtype: int64

# %% [markdown]
# As expected, most reviews are detected as being in English, since reviews were collected from the Great Britain appstore.

# %%
# Look at reviews where the language could not be detected
df.loc[df['lang-r']=='language not detected']
# Out:
#       review_id  rating               title           review_date  user_name  \
# 69   3734013494       5  One of the realest  2019-02-04T23:53:47Z  DeanBlunt
# 123  5527186972       5            makibg75  2020-02-13T21:17:28Z   makibg75
#
#     review  response_id dev_response response_date                 lang-r
# 69       🍑          NaN          NaN           NaN  language not detected
# 123      🙌          NaN          NaN           NaN  language not detected

# %% [markdown]
# Two reviews where the language could not be detected are made of emoticones.

# %%
# Look at the reviews where the languages is neither French, English or not detected
df.loc[(df['lang-r']!='en')
       &(df['lang-r']!='language not detected')].sort_values(by='lang-r').head(23)
# Out:
#       review_id  rating                                  title  \
# 36   2599431784       5                              Very good
# 41   5458614134       5                              Great app
# 126  4102003763       5                                V. Good
# 65   4812621500       5                              Great app
# 141  3311259676       5     Caracteristicas del aire oportuno.
# 46   2516097380       3               Useful but some glitches
# 101  3593000020       5                                  Great
# 104  5849975615       5                                     Hi
# 236  5356697087       5                              Great app
# 89   5725223295       5                                  great
# 68   3924884754       5               the best air quality app
# 39   5242697919       5                               Good app
# 125  5333966559       5                                  Супер
# 106  5434968121       5                                   good
# 108  3776056675       5                                     Mr
# 127  5324794536       4                              Jamshiddd
# 100  3756073061       5                               Good app
# 105  3714328090       5                                很不错的app
# 202  5504657430       5  It’s really good . I used every times
# 81   3878757449       5                   Great app to guide U
# 128  3984979306       5                           每个中国人都需要的app
# 140  3476722449       5                            非常好用，秒杀国内软件
# 129  3863166800       5                                     好用
#
#               review_date               user_name  \
# 36   2018-05-26T15:44:04Z             Theworldis!
# 41   2020-01-28T13:45:19Z                   UKNPN
# 126  2019-05-05T02:17:37Z                  jagmes
# 65   2019-09-21T01:39:54Z            ChungChungvn
# 141  2018-10-17T07:41:13Z               CharliePT
# 46   2018-05-07T13:03:03Z          qdgnjfdjydgkbb
# 101  2018-12-30T21:25:27Z             Killmallock
# 104  2020-04-22T22:20:20Z               stolarzuk
# 236  2020-01-03T19:41:39Z                 SRD7142
# 89   2020-03-28T09:37:22Z               kisne4444
# 68   2019-03-25T11:34:52Z              Pensionaru
# 39   2019-12-07T05:05:30Z               Bean thối
# 125  2019-12-29T10:03:03Z             niki_kolev1
# 106  2020-01-22T14:07:23Z              mojtabanik
# 108  2019-02-16T10:56:16Z              davalaaaar
# 127  2019-12-27T05:48:43Z               jamshiddd
# 100  2019-02-11T01:55:30Z                 vgazdag
# 105  2019-01-31T00:39:07Z          fo in my heart
# 202  2020-02-08T17:13:48Z  chedoy ru l is fr TY h
# 81   2019-03-14T02:35:35Z                 Jonuk67
# 128  2019-04-08T03:38:40Z             baba8888888
# 140  2018-11-30T10:02:45Z                     大好蛋
# 129  2019-03-10T00:24:36Z             Lok Kam Kau
#
#                                                 review  response_id  \
# 36                                          Works well          NaN
# 41                                 Keep the good work!          NaN
# 126                                            V. Good          NaN
# 65                                               Fast.          NaN
# 141  Es de suma importancia saber con antelación la...          NaN
# 46                                           See title          NaN
# 101                                           V useful          NaN
# 104                                          Super app          NaN
# 236                  Gives you visual pollution rates.          NaN
# 89                                          so usefull          NaN
# 68                                            nice app          NaN
# 39                               Excellent app we need          NaN
# 125                           Много полезно приложение          NaN
# 106                                                 ok          NaN
# 108                                               Good          NaN
# 127                                          Jamshiddd          NaN
# 100                                               Good          NaN
# 105                                               Good          NaN
# 202                                      And I’m happy          NaN
# 81                                             Oh yes.          NaN
# 128                                          希望蓝天能重回中国          NaN
# 140                               非常好用，秒杀国内软件，实际风向非常准确          NaN
# 129                                        這個apps真的好好用          NaN
#
#     dev_response response_date lang-r
# 36           NaN           NaN     af
# 41           NaN           NaN     af
# 126          NaN           NaN     af
# 65           NaN           NaN     de
# 141          NaN           NaN     es
# 46           NaN           NaN     et
# 101          NaN           NaN     et
# 104          NaN           NaN     fr
# 236          NaN           NaN     fr
# 89           NaN           NaN     it
# 68           NaN           NaN     it
# 39           NaN           NaN     nl
# 125          NaN           NaN     ru
# 106          NaN           NaN     sk
# 108          NaN           NaN     so
# 127          NaN           NaN     so
# 100          NaN           NaN     so
# 105          NaN           NaN     so
# 202          NaN           NaN     sv
# 81           NaN           NaN     tr
# 128          NaN           NaN  zh-cn
# 140          NaN           NaN  zh-cn
# 129          NaN           NaN  zh-tw

# %% [markdown]
# When the review is short, especially if there is a typo, the language detection is not correct. Will manually remove reviews where language detected is Spanish, Russian, Chinese Mandarin, and Taiwanese Mandarin.

# %%
# check cases where language review is not French or English
dfout = df.loc[(df['lang-r']!='es')&(df['lang-r']!='ru')&(df['lang-r']!='zh-cn')&(df['lang-r']!='zh-tw')]

# %%
dfout['lang'] = 'en'

# %%
del dfout['lang-r']

# %%
dfout.head()
# Out:
#     review_id  rating                      title           review_date  \
# 0  4915894551       5           A tragic reality  2019-10-10T01:06:52Z
# 1  5387399470       5  Really useful information  2020-01-11T01:19:08Z
# 2  4057061182       5            Air quality app  2019-04-25T07:07:47Z
# 3  4858351034       5        Accurate & Reliable  2019-09-29T07:38:33Z
# 4  3883883779       5           Best aqi app yet  2019-03-15T12:07:55Z
#
#          user_name                                             review  \
# 0          Si & Ro  Amazingly helpful app, both for health and as ...
# 1           Suez62  We have an ‘eco’ woodburner and as an asthmati...
# 2  # alone at xmas  I was introduced to this app via a friend who ...
# 3       r2thebizel  Very clear, easy to use and engaging. Very rel...
# 4          jhugs43  I’ve tried several aqi apps over the years, mo...
#
#    response_id dev_response response_date lang
# 0          NaN          NaN           NaN   en
# 1          NaN          NaN           NaN   en
# 2          NaN          NaN           NaN   en
# 3          NaN          NaN           NaN   en
# 4          NaN          NaN           NaN   en

# %% [markdown]
# ## Sort data

# %%
dfout.sort_values(by=['lang','rating','review_date'], inplace = True, ascending = False)

# %%
dfout
# Out:
#       review_id  rating                                 title  \
# 84   6102009673       5                               Klarkov
# 57   6090391442       5                The only essential app
# 96   6024828701       5                              Kate1290
# 85   5986928118       5                                  Good
# 14   5952085335       5  Simple, easy to use and very helpful
# ..          ...     ...                                   ...
# 34   2340258010       2                                Poorly
# 230  1643271194       2                      User experience?
# 124  1385080584       2                   Widget not working.
# 63   4902507071       1                      Accuracy concern
# 217  1950457567       1                  App language problem
#
#               review_date             user_name  \
# 84   2020-06-20T22:32:21Z               klarkov
# 57   2020-06-18T06:29:17Z               Micrian
# 96   2020-06-02T07:50:03Z              1290Kate
# 85   2020-05-24T08:01:51Z      Tethanskronosdia
# 14   2020-05-16T08:08:24Z  Super_sonic-saiyajin
# ..                    ...                   ...
# 34   2018-03-24T08:00:33Z              Gosoo123
# 230  2017-06-13T18:46:29Z               Karl219
# 124  2016-05-28T00:51:58Z              david171
# 63   2019-10-07T02:49:33Z               Long181
# 217  2017-11-26T15:06:39Z           Cheeserolly
#
#                                                 review  response_id  \
# 84                                       Love this app          NaN
# 57   Would like to see this data being used to brin...          NaN
# 96   As a mother with children in year 01 and year ...          NaN
# 85                                            Good app          NaN
# 14   So far so good!! This app is quite useful and ...          NaN
# ..                                                 ...          ...
# 34            It isn’t online if reads 12 times a day.          NaN
# 230  How can you fail to make deleting a weather st...          NaN
# 124  The widget does not work, no matter what diffe...          NaN
# 63   I have high concern about accuracy of the meas...          NaN
# 217  I speak English but live in Taiwan. The AirVis...          NaN
#
#     dev_response response_date lang
# 84           NaN           NaN   en
# 57           NaN           NaN   en
# 96           NaN           NaN   en
# 85           NaN           NaN   en
# 14           NaN           NaN   en
# ..           ...           ...  ...
# 34           NaN           NaN   en
# 230          NaN           NaN   en
# 124          NaN           NaN   en
# 63           NaN           NaN   en
# 217          NaN           NaN   en
#
# [238 rows x 10 columns]

# %% [markdown]
# ## Export data

# %%
# export to csv
dfout.to_csv('app_reviews_airvisual-air-quality-forecast_1048912974_by_lang_gb.csv', encoding='utf-8-sig', sep =';')
