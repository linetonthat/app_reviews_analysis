# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Preprocessing,-exploration-and-export-of-app-reviews-[Sensio---USA-appstore]" data-toc-modified-id="Preprocessing,-exploration-and-export-of-app-reviews-[Sensio---USA-appstore]-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Preprocessing, exploration and export of app reviews [Sensio - USA appstore]</a></span><ul class="toc-item"><li><span><a href="#Load-data" data-toc-modified-id="Load-data-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Load data</a></span></li><li><span><a href="#Ratings" data-toc-modified-id="Ratings-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Ratings</a></span></li><li><span><a href="#Detect-language" data-toc-modified-id="Detect-language-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Detect language</a></span></li><li><span><a href="#Sort-data" data-toc-modified-id="Sort-data-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Sort data</a></span></li><li><span><a href="#Export-data" data-toc-modified-id="Export-data-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Export data</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Preprocessing, exploration and export of app reviews [Sensio - USA appstore]

# %% [markdown]
# We have scraped reviews on a [specific app](https://apps.apple.com/us/app/airvisual-qualit%C3%A9-de-lair/id1048912974#see-all/reviews) in the French appstore. This app is related to air quality. Our goal is to analyse these reviews to try to find out about :
# * usages
# * most relevant app features
# * "missing" app features, or features that users would like the app to have
# * technical issues.
#
# Data preparation will be key to help analyse the reviews, such as sorting reviews according to selected criteria.  This will also give us the opportunity to test some NLP tools as needed (language detection, sentiment analysis...).

# %%
import pandas as pd
from langdetect import detect
import warnings
warnings.filterwarnings('ignore')
import os

# %% [markdown]
# ## Load data

# %%
path = os.getcwd()
filename ='app_reviews_sensio_us.json'

# %%
df = pd.read_json(path+"/../data/0_scraped_data/"+filename)

# %%
df.head()
# Out:
#     review_id  rating                                              title  \
# 0  2579715523       4                               More updates to come
# 1  2714285310       3  Is not tracking my symptoms but is still helpful.
# 2  3650933831       4                                   So far, so good!
# 3  5201671987       1                        FORCED TO CREATE AN ACCOUNT
# 4  3174901787       3              One day, this may become a great app.
#
#             review_date      user_name  \
# 0  2018-05-22T05:13:01Z  Samsoumitunes
# 1  2018-06-17T22:01:32Z       p-money7
# 2  2019-01-15T00:44:27Z      egretsrus
# 3  2019-11-27T02:36:05Z      Topbridge
# 4  2018-09-10T14:00:07Z  APColliflower
#
#                                               review  response_id  \
# 0  I am sure this app will be like a fundamental ...    5175794.0
# 1  I want to love this app, but I’ve been logging...    3893613.0
# 2  How can I delete the daily notifications? They...    6848026.0
# 3  I HATE HATE H A T E apps that force you to sig...          NaN
# 4  I wish that the app tracked my area.  I live i...    6390681.0
#
#                                         dev_response         response_date
# 0  Thank you for your comment! We love getting yo...  2018-09-22T18:48:20Z
# 1  Thank you for your feedback! You need to log y...  2018-06-19T11:17:10Z
# 2  Thanks for your comment, buses and tubes are c...  2019-01-15T14:14:11Z
# 3                                                NaN                   NaN
# 4  Hello, thank you very much for your feedback a...  2018-12-14T16:54:38Z

# %%
df.columns
# Out:
# Index(['review_id', 'rating', 'title', 'review_date', 'user_name', 'review',
#        'response_id', 'dev_response', 'response_date'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   review_id      26 non-null     int64
#  1   rating         26 non-null     int64
#  2   title          26 non-null     object
#  3   review_date    26 non-null     object
#  4   user_name      26 non-null     object
#  5   review         26 non-null     object
#  6   response_id    17 non-null     float64
#  7   dev_response   17 non-null     object
#  8   response_date  17 non-null     object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 2.0+ KB

# %%
df['review']
# Out:
# 0     I am sure this app will be like a fundamental ...
# 1     I want to love this app, but I’ve been logging...
# 2     How can I delete the daily notifications? They...
# 3     I HATE HATE H A T E apps that force you to sig...
# 4     I wish that the app tracked my area.  I live i...
# 5     I wish that the app tracked my area.  I live i...
# 6     I wish that the app tracked my area.  I live i...
# 7     If yiu believe the adage that you can only imp...
# 8     Love the app, it really packs lots of features...
# 9     Have had too many glitchy problems getting inf...
# 10    Great product, very helpful to anybody that is...
# 11    What an incredible app!!! Not only is it easy ...
# 12    App seems like it would be great but is greatl...
# 13    Maybe I’m missing something? But the app doesn...
# 14                          Sets it apart from everyone
# 15    I live in Indiana, United States. There are on...
# 16                   Great way to monitor air quality !
# 17    This app makes no sense if you are unable to g...
# 18    The locations in the app do not contain a lot ...
# 19    Font is way too small and no apparent way to a...
# 20                                        No Anchorage?
# 21    I would love to be able to use this app, howev...
# 22    Would love this app if it even covered part of...
# 23                                   This is a awesome!
# 24    It’s nice to see daily allergy reports, but if...
# 25    $19.99 subscription fee to get a report, hardl...
# Name: review, dtype: object

# %% [markdown]
# ## Ratings

# %%
# assess the distribution of ratings
df['rating'].value_counts()
# Out:
# 5    7
# 2    6
# 1    6
# 3    5
# 4    2
# Name: rating, dtype: int64

# %%
# assess mean rating
df['rating'].mean()
# Out:
# 2.923076923076923

# %% [markdown]
# ## Detect language

# %%
# Define a function to identify language and catch exceptions
def lang_detect(text):
    # use deterministic approach for language detection
    from langdetect import DetectorFactory
    DetectorFactory.seed = 0
    try:
        return detect(text)
    except:
        return "language not detected"

# %%
# Detect the language used in the reviews
df['lang-r'] = df['review'].apply(lang_detect)

# %%
# What are the detected languages?
df['lang-r'].unique()
# Out:
# array(['en'], dtype=object)

# %% [markdown]
# ## Sort data

# %%
dfout = df.sort_values(by=['lang-r','rating','review_date'], ascending = False)

# %%
dfout
# Out:
#      review_id  rating                                              title  \
# 8   4125441347       5            Great way to keep track of my allergies
# 14  3630990329       5                        You can write your symptoms
# 11  2612985502       5                                       Awesome App!
# 10  2609528181       5  Finally an app that can help me manage my alle...
# 23  2592144865       5                                          Brilliant
# 16  1795231875       5                                          Great App
# 7   1775601497       5               A great idea that's well implemented
# 2   3650933831       4                                   So far, so good!
# 0   2579715523       4                               More updates to come
# 20  5992518406       3                                        Poor Alaska
# 4   3174901787       3              One day, this may become a great app.
# 5   3174901790       3              One day, this may become a great app.
# 6   3174901765       3              One day, this may become a great app.
# 1   2714285310       3  Is not tracking my symptoms but is still helpful.
# 15  5898579801       2                                           Location
# 24  5653413703       2                                   High Monthly Fee
# 19  4825718335       2                                            Poor UI
# 12  4051165416       2                               Needs more locations
# 18  3804188241       2                 Missing Cities for Allergen Alerts
# 9   3230083266       2                                  Too many problems
# 13  5580665537       1        App doesn’t find my location, Florida, U.S.
# 3   5201671987       1                        FORCED TO CREATE AN ACCOUNT
# 25  4678160765       1  Not ready for prime time - high report cost - ...
# 17  4254006354       1                                           Location
# 21  3221852234       1                         Not In My Area of Missouri
# 22  3033171034       1                                     Not in my area
#
#              review_date                      user_name  \
# 8   2019-05-09T20:56:28Z                           Cylb
# 14  2019-01-09T18:44:04Z             professoor scripts
# 11  2018-05-29T15:31:23Z                    Momma Berta
# 10  2018-05-28T21:38:56Z                  Richard jolio
# 23  2018-05-25T03:03:39Z                 Ahmad muhaisen
# 16  2017-09-17T22:01:52Z                       Tiger701
# 7   2017-09-05T19:56:20Z                   David Haddad
# 2   2019-01-15T00:44:27Z                      egretsrus
# 0   2018-05-22T05:13:01Z                  Samsoumitunes
# 20  2020-05-25T15:49:12Z              TheOneThatMatters
# 4   2018-09-10T14:00:07Z                  APColliflower
# 5   2018-09-10T14:00:07Z                  APColliflower
# 6   2018-09-10T14:00:07Z                  APColliflower
# 1   2018-06-17T22:01:32Z                       p-money7
# 15  2020-05-03T18:40:05Z                      Jojo56789
# 24  2020-03-13T06:23:06Z                        MezzoMH
# 19  2019-09-23T00:05:09Z                          mw212
# 12  2019-04-23T18:49:58Z                   Wildwoodflwr
# 18  2019-02-23T09:44:29Z                Allergy Tracker
# 9   2018-09-25T23:43:23Z                    Kevin_in_cs
# 13  2020-02-26T01:43:15Z             AmandaElizabeth520
# 3   2019-11-27T02:36:05Z                      Topbridge
# 25  2019-08-26T17:33:29Z                 HollyYarbrough
# 17  2019-06-02T22:07:47Z              Jsjdbeosnfogneoap
# 21  2018-09-23T15:55:51Z                   Mason Newman
# 22  2018-08-08T02:04:22Z  allowstatecheckbeforedownload
#
#                                                review  response_id  \
# 8   Love the app, it really packs lots of features...    8699613.0
# 14                        Sets it apart from everyone    6766230.0
# 11  What an incredible app!!! Not only is it easy ...    5175773.0
# 10  Great product, very helpful to anybody that is...    5175778.0
# 23                                 This is a awesome!          NaN
# 16                 Great way to monitor air quality !    5175800.0
# 7   If yiu believe the adage that you can only imp...          NaN
# 2   How can I delete the daily notifications? They...    6848026.0
# 0   I am sure this app will be like a fundamental ...    5175794.0
# 20                                      No Anchorage?          NaN
# 4   I wish that the app tracked my area.  I live i...    6390681.0
# 5   I wish that the app tracked my area.  I live i...          NaN
# 6   I wish that the app tracked my area.  I live i...    5175763.0
# 1   I want to love this app, but I’ve been logging...    3893613.0
# 15  I live in Indiana, United States. There are on...          NaN
# 24  It’s nice to see daily allergy reports, but if...   14656638.0
# 19  Font is way too small and no apparent way to a...          NaN
# 12  App seems like it would be great but is greatl...    8434449.0
# 18  The locations in the app do not contain a lot ...    8446282.0
# 9   Have had too many glitchy problems getting inf...    6390653.0
# 13  Maybe I’m missing something? But the app doesn...   14655143.0
# 3   I HATE HATE H A T E apps that force you to sig...          NaN
# 25  $19.99 subscription fee to get a report, hardl...          NaN
# 17  This app makes no sense if you are unable to g...          NaN
# 21  I would love to be able to use this app, howev...    6390662.0
# 22  Would love this app if it even covered part of...    4873784.0
#
#                                          dev_response         response_date  \
# 8              Thank you very much for your feedback!  2019-05-16T09:04:59Z
# 14          Hello, thank you for your 5 Stars Rating.  2019-01-10T09:13:29Z
# 11          Thank you so much for your kind feedback!  2018-09-22T18:43:38Z
# 10  Thank you for your feedback Richard! Don't for...  2018-09-22T18:45:09Z
# 23                                                NaN                   NaN
# 16                       Thank you for your feedback!  2018-09-22T18:49:32Z
# 7                                                 NaN                   NaN
# 2   Thanks for your comment, buses and tubes are c...  2019-01-15T14:14:11Z
# 0   Thank you for your comment! We love getting yo...  2018-09-22T18:48:20Z
# 20                                                NaN                   NaN
# 4   Hello, thank you very much for your feedback a...  2018-12-14T16:54:38Z
# 5                                                 NaN                   NaN
# 6   Thank you very much for your feedback, we're v...  2018-09-22T18:39:24Z
# 1   Thank you for your feedback! You need to log y...  2018-06-19T11:17:10Z
# 15                                                NaN                   NaN
# 24  Hello, thank you for your feedback. It is curr...  2020-04-14T11:07:28Z
# 19                                                NaN                   NaN
# 12  Hello and thank you for your feedback. We are ...  2019-04-29T16:06:38Z
# 18  Hello, we are currently in the process of addi...  2019-04-30T09:27:54Z
# 9   Hello Kevin, Thank you for your feedback. Than...  2018-12-14T16:52:46Z
# 13  Hello, if the app is not finding your current ...  2020-04-14T10:07:42Z
# 3                                                 NaN                   NaN
# 25                                                NaN                   NaN
# 17                                                NaN                   NaN
# 21  Hello Mason, thank you for your feedback. We a...  2018-12-14T16:53:23Z
# 22  Hello thanks for your feedback, indeed we do n...  2018-08-30T12:19:11Z
#
#    lang-r
# 8      en
# 14     en
# 11     en
# 10     en
# 23     en
# 16     en
# 7      en
# 2      en
# 0      en
# 20     en
# 4      en
# 5      en
# 6      en
# 1      en
# 15     en
# 24     en
# 19     en
# 12     en
# 18     en
# 9      en
# 13     en
# 3      en
# 25     en
# 17     en
# 21     en
# 22     en

# %% [markdown]
# ## Export data

# %%
export_filename = filename[:-5]+'.csv'
print(export_filename)
# Out:
# app_reviews_sensio_us.csv

# %%
# exporta to csv
dfout.to_csv(path+"/../data/1_preprocessed_data/"+export_filename, encoding='utf-8-sig', sep =';')
