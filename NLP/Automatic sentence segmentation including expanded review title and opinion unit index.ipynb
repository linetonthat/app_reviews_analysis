# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Segment-expanded-titles-and-reviews-in-order-to-extract-&quot;opinion-units&quot;" data-toc-modified-id="Segment-expanded-titles-and-reviews-in-order-to-extract-&quot;opinion-units&quot;-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Segment expanded titles and reviews in order to extract "opinion units"</a></span><ul class="toc-item"><li><span><a href="#Load-reviews" data-toc-modified-id="Load-reviews-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Load reviews</a></span></li><li><span><a href="#Modify-rules-for-sentence-segmentation" data-toc-modified-id="Modify-rules-for-sentence-segmentation-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Modify rules for sentence segmentation</a></span></li><li><span><a href="#Removing-line-breaks" data-toc-modified-id="Removing-line-breaks-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Removing line breaks</a></span></li><li><span><a href="#Extract-opinion-units" data-toc-modified-id="Extract-opinion-units-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Extract opinion units</a></span></li><li><span><a href="#Create-new-dataframe-with-opinion-units" data-toc-modified-id="Create-new-dataframe-with-opinion-units-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Create new dataframe with opinion units</a></span></li><li><span><a href="#Export-file" data-toc-modified-id="Export-file-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Export file</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Segment expanded titles and reviews in order to extract "opinion units"
# When users write reviews, they may provide their opinion on different aspects of the app (cf. __[this website](https://monkeylearn.com/blog/aspect-based-sentiment-analysis/)__). They might like one feature from the app, and whish another one was better. Also, in order to assess what topic are of highest interest, we'd like to segment app reviews in ordre to extract "opinion units" from users.
#
# After reading some app reviews, we've identified how to modify the default rules from spaCy to extract opinion units from our app reviews:
# * Use the default sentence segmentation from spaCy
# * Add a rule to the pipeline before the parser, to segment when "but" or "althoug" are used.
# * Change the rule to never segment when "so" is encountered
# Empty lines should also be removed.
#
# Here, since our dataset is not too large, we'll duplicate the review information and associate it with each opinion unit.
#
# NB: After going through reviews to identify topics, tags and sentiment, I've realized that for certain reviews, information is mostly in the title. Will add the review title as an opinion unit. Will also add an index for the opinion units, as it may make tagging (topics, sentiment) easier.

# %%
import os
import pandas as pd

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ## Load reviews

# %%
path = os.getcwd()
filename = 'app_reviews_airvisual-air-quality-forecast_1048912974_by_lang_us_exp_abb.csv'
subfolder = '/../data/1_preprocessed_data/'

# %%
df = pd.read_csv(path+subfolder+filename)

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1   review_id  rating  \
# 0           0          3095  6121840341       5
# 1           1           982  6114444527       5
# 2           2          1965  6114325210       5
# 3           3           797  6111838742       5
# 4           4           962  6104666348       5
#
#                                                title           review_date  \
# 0  Happy to finally see when and why I can’t brea...  2020-06-25T23:18:57Z
# 1                                              Super  2020-06-24T02:12:59Z
# 2                                          Great App  2020-06-24T01:31:38Z
# 3                    Great app for filtering the air  2020-06-23T11:01:04Z
# 4                                    I look everyday  2020-06-21T14:29:25Z
#
#         user_name                                             review  \
# 0      Abbsteroni  Having allergies is annoying but I’m glad to s...
# 1       WillJosue         Easy to keep track on specific Local areas
# 2       Nejinater                          Full of good information!
# 3      Jamieissad  Tells you everything you need to know about th...
# 4  TorchPitchfork  This is part of my daily planning. I love the ...
#
#    response_id dev_response response_date lang  \
# 0          NaN          NaN           NaN   en
# 1          NaN          NaN           NaN   en
# 2          NaN          NaN           NaN   en
# 3          NaN          NaN           NaN   en
# 4          NaN          NaN           NaN   en
#
#                                       title_expanded  \
# 0  Happy to finally see when and why I ca n’t bre...
# 1                                              Super
# 2                                          Great App
# 3                    Great app for filtering the air
# 4                                    I look everyday
#
#                                      review_expanded
# 0  Having allergies is annoying but I ’m glad to ...
# 1         Easy to keep track on specific Local areas
# 2                         Full of good information !
# 3  Tells you everything you need to know about th...
# 4  This is part of my daily planning . I love the...

# %% [markdown]
# ## Modify rules for sentence segmentation

# %%
# modify rules before the parser in the pipeline
def set_custom_boundaries(doc):
    for token in doc[:-1]:
        # segment at "but" and "although"
        if token.text == 'but' or token.text == 'although':
            doc[token.i].is_sent_start = True
        # never segment at "so"
        elif token.text == 'so':
            doc[token.i].is_sent_start = False
    return doc
            
nlp.add_pipe(set_custom_boundaries, before = 'parser')

nlp.pipe_names
# Out:
# ['tagger', 'set_custom_boundaries', 'parser', 'ner']

# %%
# check the application of the new rules
s = "love using this to check the air quality in my area and whenever I travel, but not at work. i like that it has the widget option so i can see it in my today view as well on iphone"

doc8 = nlp(s)
for sent in doc8.sents:
    print(sent.text)
# Out:
# love using this to check the air quality in my area and whenever I travel,
# but not at work.
# i like that it has the widget option so i can see it in my today view as well on iphone

# %% [markdown]
# ## Removing line breaks

# %%
import re

# %%
clean_line_break = lambda s : ' '.join(re.findall('[^\n]+', s))

# %% [markdown]
# ## Extract opinion units

# %%
extract_sent = lambda s : [clean_line_break(sent.text) for sent in nlp(s).sents]

# %%
extract_sent(s)
# Out:
# ['love using this to check the air quality in my area and whenever I travel,',
#  'but not at work.',
#  'i like that it has the widget option so i can see it in my today view as well on iphone']

# %%
s2 = df.iloc[2147]['review_expanded']

# %%
extract_sent(s2)

# %%
df['opinion_units'] = df['review_expanded'].apply(extract_sent)

# %%
df.iloc[300:310]
# Out:
#      Unnamed: 0  Unnamed: 0.1   review_id  rating  \
# 300         300          1817  5242021261       5
# 301         301          1948  5240900262       5
# 302         302           480  5237483737       5
# 303         303           801  5237080060       5
# 304         304          2471  5236021069       5
# 305         305          2027  5235194088       5
# 306         306           135  5234638862       5
# 307         307          1408  5234247246       5
# 308         308          1210  5234243444       5
# 309         309          2172  5234131774       5
#
#                                                  title           review_date  \
# 300  Super amazing app that helped during the CA wi...  2019-12-07T00:59:33Z
# 301                                           Good app  2019-12-06T17:19:08Z
# 302                  Helpful app for local air quality  2019-12-05T20:41:34Z
# 303                                  Very helpful app!  2019-12-05T17:55:48Z
# 304                                 Reza tavakoli khoo  2019-12-05T12:19:12Z
# 305                                      So useful app  2019-12-05T07:32:49Z
# 306                   So accurate and a MUST HAVE!!!!!  2019-12-05T04:02:05Z
# 307                    Love that it keeps me informed!  2019-12-05T01:32:13Z
# 308                                 Seems great so far  2019-12-05T01:30:36Z
# 309                                       Awesome App!  2019-12-05T00:43:56Z
#
#               user_name                                             review  \
# 300            Davis-DD  LIFE SAVING, literally\nINDISPENSABLE  way to ...
# 301              Nesta8  Very helpful app, but Widget crashes on iphone xs
# 302    Hfrencijdbsijcen  This app has been helpful for looking up local...
# 303            Evpraxia  This app helps me prepare for the day and the ...
# 304  reza tavakoli khoo                             Perfect app and useful
# 305         Enkhamgalan          I’m glad to know this app. Super cool app
# 306                7207  I found this app from my Dr during the CA fire...
# 307           cfsama420  Very helpful! Let’s me know to stay inside on ...
# 308     Summit mountain  Nice dashboard approach and specific multiple ...
# 309            Zuriwang                   This app is extremely helpful 👍🏾
#
#      response_id dev_response response_date lang  \
# 300          NaN          NaN           NaN   en
# 301          NaN          NaN           NaN   en
# 302          NaN          NaN           NaN   en
# 303          NaN          NaN           NaN   en
# 304          NaN          NaN           NaN   en
# 305          NaN          NaN           NaN   en
# 306          NaN          NaN           NaN   en
# 307          NaN          NaN           NaN   en
# 308          NaN          NaN           NaN   en
# 309          NaN          NaN           NaN   en
#
#                                         title_expanded  \
# 300  Super amazing app that helped during the Calif...
# 301                                           Good app
# 302                  Helpful app for local air quality
# 303                                 Very helpful app !
# 304                                 Reza tavakoli khoo
# 305                                      So useful app
# 306              So accurate and a MUST HAVE ! ! ! ! !
# 307                   Love that it keeps me informed !
# 308                                 Seems great so far
# 309                                      Awesome App !
#
#                                        review_expanded  \
# 300  LIFE SAVING , literally \n INDISPENSABLE   way...
# 301  Very helpful app , but Widget crashes on iphon...
# 302  This app has been helpful for looking up local...
# 303  This app helps me prepare for the day and the ...
# 304                             Perfect app and useful
# 305        I ’m glad to know this app . Super cool app
# 306  I found this app from my Doctor during the Cal...
# 307  Very helpful ! Let ’s me know to stay inside o...
# 308  Nice dashboard approach and specific multiple ...
# 309                  This app is extremely helpful 👍 🏾
#
#                                          opinion_units
# 300  [LIFE SAVING , literally   INDISPENSABLE   way...
# 301  [Very helpful app ,, but Widget crashes on iph...
# 302  [This app has been helpful for looking up loca...
# 303  [This app helps me prepare for the day and the...
# 304                           [Perfect app and useful]
# 305     [I ’m glad to know this app ., Super cool app]
# 306  [I found this app from my Doctor during the Ca...
# 307  [Very helpful !, Let ’s me know to stay inside...
# 308  [Nice dashboard approach and specific multiple...
# 309                [This app is extremely helpful 👍 🏾]

# %%
df.iloc[305]['opinion_units']
# Out:
# ['I ’m glad to know this app .', 'Super cool app']

# %% [markdown]
# ## Create new dataframe with opinion units

# %%
cols = df.columns.values.tolist()
cols.append('opi_id')
cols
# Out:
# ['Unnamed: 0',
#  'Unnamed: 0.1',
#  'review_id',
#  'rating',
#  'title',
#  'review_date',
#  'user_name',
#  'review',
#  'response_id',
#  'dev_response',
#  'response_date',
#  'lang',
#  'title_expanded',
#  'review_expanded',
#  'opinion_units',
#  'opi_id']

# %%
df_out = pd.DataFrame(columns = cols)

# %%
df_out
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 0.1, review_id, rating, title, review_date, user_name, review, response_id, dev_response, response_date, lang, title_expanded, review_expanded, opinion_units, opi_id]
# Index: []

# %%
# method to use the title as an additional opinion unit
def get_title_opinion(df, i, counter):
    
    title_r = {}
    
    # copy the info from all the columns except the last one
    for c in df.columns[:-1]:
        title_r[c] = df.iloc[i].loc[c]
        
    # extract the title review to fill the 'opinion_units' column
    opinion_c = df.columns[-1]
    title_r[opinion_c] = df.iloc[i].loc['title_expanded']
    
    # add the id of the opinion unit
    title_r['opi_id'] = counter
    
    return title_r

# %%
get_title_opinion(df, 0, 0)
# Out:
# {'Unnamed: 0': 0,
#  'Unnamed: 0.1': 3095,
#  'review_id': 6121840341,
#  'rating': 5,
#  'title': 'Happy to finally see when and why I can’t breathe!',
#  'review_date': '2020-06-25T23:18:57Z',
#  'user_name': 'Abbsteroni',
#  'review': 'Having allergies is annoying but I’m glad to see this and know when to take extra precautions.',
#  'response_id': nan,
#  'dev_response': nan,
#  'response_date': nan,
#  'lang': 'en',
#  'title_expanded': 'Happy to finally see when and why I ca n’t breathe !',
#  'review_expanded': 'Having allergies is annoying but I ’m glad to see this and know when to take extra precautions .',
#  'opinion_units': 'Happy to finally see when and why I ca n’t breathe !',
#  'opi_id': 0}

# %%
# method to define the content of the row for the dataframe of opinion units
def new_row(df, i, j, counter):
    
    new_r = {}
    
    # copy the info from all the columns except the last one
    for c in df.columns[:-1]:
        new_r[c] = df.iloc[i].loc[c]
        
    # extract the j th item from the list in the 'opinion_units' column of df
    opinion_c = df.columns[-1]
    new_r[opinion_c] = df.iloc[i].loc[opinion_c][j]
    
    # add the id of the opinion unit
    new_r['opi_id'] = counter
    
    return new_r

# %%
opinion_c = df.columns[-1]
counter = 0

# build the dataframe of opinion units
for i in range(len(df)): 
#for i in range(20): 
    
    # add a row to extract the review title as an opinion unit
    new_r = get_title_opinion(df, i, counter)
    df_out = df_out.append(new_r, ignore_index=True)
    counter += 1
    
    # add row(s) from opinion units extracted from the review
    lst_len = len(df.iloc[i].loc[opinion_c])
    
    for j in range(lst_len):
        new_r = new_row(df, i, j, counter)
        df_out = df_out.append(new_r, ignore_index=True)
        counter += 1

# %%
# rename the last columns
df_out.rename({'opinion_units':'opinion_unit'}, axis = 1, inplace = True)

# %%
df_out.head(10)
# Out:
#   Unnamed: 0 Unnamed: 0.1   review_id rating  \
# 0          0         3095  6121840341      5
# 1          0         3095  6121840341      5
# 2          0         3095  6121840341      5
# 3          1          982  6114444527      5
# 4          1          982  6114444527      5
# 5          2         1965  6114325210      5
# 6          2         1965  6114325210      5
# 7          3          797  6111838742      5
# 8          3          797  6111838742      5
# 9          4          962  6104666348      5
#
#                                                title           review_date  \
# 0  Happy to finally see when and why I can’t brea...  2020-06-25T23:18:57Z
# 1  Happy to finally see when and why I can’t brea...  2020-06-25T23:18:57Z
# 2  Happy to finally see when and why I can’t brea...  2020-06-25T23:18:57Z
# 3                                              Super  2020-06-24T02:12:59Z
# 4                                              Super  2020-06-24T02:12:59Z
# 5                                          Great App  2020-06-24T01:31:38Z
# 6                                          Great App  2020-06-24T01:31:38Z
# 7                    Great app for filtering the air  2020-06-23T11:01:04Z
# 8                    Great app for filtering the air  2020-06-23T11:01:04Z
# 9                                    I look everyday  2020-06-21T14:29:25Z
#
#         user_name                                             review  \
# 0      Abbsteroni  Having allergies is annoying but I’m glad to s...
# 1      Abbsteroni  Having allergies is annoying but I’m glad to s...
# 2      Abbsteroni  Having allergies is annoying but I’m glad to s...
# 3       WillJosue         Easy to keep track on specific Local areas
# 4       WillJosue         Easy to keep track on specific Local areas
# 5       Nejinater                          Full of good information!
# 6       Nejinater                          Full of good information!
# 7      Jamieissad  Tells you everything you need to know about th...
# 8      Jamieissad  Tells you everything you need to know about th...
# 9  TorchPitchfork  This is part of my daily planning. I love the ...
#
#    response_id dev_response response_date lang  \
# 0          NaN          NaN           NaN   en
# 1          NaN          NaN           NaN   en
# 2          NaN          NaN           NaN   en
# 3          NaN          NaN           NaN   en
# 4          NaN          NaN           NaN   en
# 5          NaN          NaN           NaN   en
# 6          NaN          NaN           NaN   en
# 7          NaN          NaN           NaN   en
# 8          NaN          NaN           NaN   en
# 9          NaN          NaN           NaN   en
#
#                                       title_expanded  \
# 0  Happy to finally see when and why I ca n’t bre...
# 1  Happy to finally see when and why I ca n’t bre...
# 2  Happy to finally see when and why I ca n’t bre...
# 3                                              Super
# 4                                              Super
# 5                                          Great App
# 6                                          Great App
# 7                    Great app for filtering the air
# 8                    Great app for filtering the air
# 9                                    I look everyday
#
#                                      review_expanded  \
# 0  Having allergies is annoying but I ’m glad to ...
# 1  Having allergies is annoying but I ’m glad to ...
# 2  Having allergies is annoying but I ’m glad to ...
# 3         Easy to keep track on specific Local areas
# 4         Easy to keep track on specific Local areas
# 5                         Full of good information !
# 6                         Full of good information !
# 7  Tells you everything you need to know about th...
# 8  Tells you everything you need to know about th...
# 9  This is part of my daily planning . I love the...
#
#                                         opinion_unit opi_id
# 0  Happy to finally see when and why I ca n’t bre...      0
# 1                       Having allergies is annoying      1
# 2  but I ’m glad to see this and know when to tak...      2
# 3                                              Super      3
# 4         Easy to keep track on specific Local areas      4
# 5                                          Great App      5
# 6                         Full of good information !      6
# 7                    Great app for filtering the air      7
# 8  Tells you everything you need to know about th...      8
# 9                                    I look everyday      9

# %% [markdown]
# ## Export file

# %%
export_filename = filename[:-4]+'_ou_v3.csv'
export_filename
# Out:
# 'app_reviews_airvisual-air-quality-forecast_1048912974_by_lang_us_exp_abb_ou_v3.csv'

# %%
export_subfolder = '/../data/2_opinion_units/'
export_subfolder
# Out:
# '/../data/2_opinion_units/'

# %%
df_out.to_csv(path+export_subfolder+export_filename)
